# %% [markdown]
# <a href="https://colab.research.google.com/github/DorodiK/ReproducibilityChallenge2021/blob/main/ada_IN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing libraries

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #### Change the directory for use

# %%
cd 'gdrive/My Drive/pytorch-AdaIN'
# Out:
# /content/gdrive/My Drive/pytorch-AdaIN

# %%
# !ls
# Out:
# function.py  models  __pycache__       results.png  test.py
# input	     net.py  README.md	       sampler.py   torch_to_pytorch.py
# LICENSE      output  requirements.txt  test_images  train.py

# %% [markdown]
# ## AdaIN Experiments
# ### 1. Experiment with bold features for style image

# %%
#Importing libraries
import cv2  
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# #### Content Image

# %%
cont1 = cv2.imread('/content/gdrive/MyDrive/pytorch-AdaIN/test_images/content/content_01.jpg')

cont1 = np.float32(cont1)

cv2_imshow(cont1)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FACFD4161D0>

# %% [markdown]
# #### Style Image

# %%
stl1 = cv2.imread('/content/gdrive/MyDrive/pytorch-AdaIN/test_images/style/style_06.png')

stl1 = np.float32(stl1)

cv2_imshow(stl1)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FACFD3CFCD0>

# %% [markdown]
# ### Running test.py with the above content and style image

# %%
# !python test.py --content '/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/content/content_01.jpg' --style '/content/gdrive/MyDrive/pytorch-AdaIN/test_images/style/style_06.png'

# %% [markdown]
# ### Output

# %%
out1 = cv2.imread('/content/gdrive/MyDrive/pytorch-AdaIN/output/content_01_stylized_style_06.jpg')
out1 = np.float32(out1)
cv2_imshow(out1)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FACFD3D8690>

# %% [markdown]
# ### 2.Experiments with intricate colour patterns

# %% [markdown]
# #### Style Image

# %%
stl2 = cv2.imread('/content/gdrive/MyDrive/pytorch-AdaIN/test_images/style/MicrosoftTeams-image.png')

stl2 = np.float32(stl2)

cv2_imshow(stl2)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FACFD3D3810>

# %%
# !python test.py --content '/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/content/content_01.jpg' --style '/content/gdrive/MyDrive/pytorch-AdaIN/test_images/style/MicrosoftTeams-image.png'

# %% [markdown]
# ### Output

# %%
out2 = cv2.imread('/content/gdrive/MyDrive/pytorch-AdaIN/output/content_01_stylized_MicrosoftTeams-image.jpg')
out2 = np.float32(out2)
cv2_imshow(out2)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FACFD3CF590>

# %% [markdown]
# ### 2.Experiments with rotation of style image

# %%
style21 = cv2.imread('/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/style/style_01.jpg')

style21 = np.float32(style21)

cv2_imshow(style21)


style22 = cv2.imread('/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/style/style_011.jpg')

style22 = np.float32(style22)

cv2_imshow(style22)

styl23 = cv2.imread('/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/style/style_012.jpg')

styl23 = np.float32(styl23)

cv2_imshow(styl23)

styl24 = cv2.imread('/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/style/style_013.jpg')

styl24 = np.float32(styl24)

cv2_imshow(styl24)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FACFCCDADD0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FACFCCDADD0>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FACFCCDAC10>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FACFCCDABD0>

# %% [markdown]
# ### Running test.py on the following images and merging the output we obtain the following video of merged outputs.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython import display
from fastai.imports import *

# %%
gifPath = Path("/content/gdrive/MyDrive/pytorch-AdaIN/output/adain.gif") 
# Display GIF in Jupyter, CoLab, IPython
with open(gifPath,'rb') as f:
    display.Image(data=f.read(), format='png')

# %% [markdown]
# ## References
#
# 1. Code obtained from [AdaIN](https://github.com/naoto0804/pytorch-AdaIN)
